# %%
X =  { " john": 82,
      "Sarah": 92,
      "ALex": 78,
      "Linda": 88,
      "david": 95
}
X["emily"] = 91
print(X)
# Out:
# {' john': 82, 'Sarah': 92, 'ALex': 78, 'Linda': 88, 'david': 95, 'emily': 91}

# %%
X['Sarah'] = 95
print(X)
# Out:
# {' john': 82, 'Sarah': 95, 'ALex': 78, 'Linda': 88, 'david': 95, 'emily': 91}

# %%
del X['ALex']
print(X)
# Out:
# {' john': 82, 'Sarah': 95, 'Linda': 88, 'david': 95, 'emily': 91}

# %%
print([x for x in X if X[x] > 90])
# Out:
# ['Sarah', 'david', 'emily']
